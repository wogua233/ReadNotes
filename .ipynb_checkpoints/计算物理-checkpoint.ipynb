# %% [markdown]
# 使用计算机时，几乎总是通过shell与计算机交流，包括高级语言（java,C,Fortran）或problem-soling环境（mathmatica,matlab），编译型语言通常更高效，因为更少使用subprogram libs

# %% [markdown]
# 可理解的编程语言经过编译和链接形成可执行文件。

# %% [markdown]
# ![image.png](attachment:8ec5725b-c9c1-4f7a-8d07-88121b31fbd9.png)

# %% [markdown]
# ![image.png](attachment:deee24f0-6356-40d6-b9a6-b5aa78964773.png)![image.png](attachment:d9d3fb04-1f2c-4597-951a-4e7e4b71719c.png)

# %% [markdown]
# 首先必须是program语句且最后有end，变量要申明类型，且首字母必须为字母，末尾不能是下划线，注释以！开头

# %% [markdown]
# (*,*)表明format

# %% [markdown]
# ![image.png](attachment:c7bff172-8285-474b-a033-db15df0258ce.png)编译方式，通常会用吗makefile使得不需要重复输入上述行

# %% [markdown]
# 对于INTEGER(KIND=n)，也可以写成INTEGER(n),n代表一个整形对应的字节，如果不指定，默认4字节（32bit）,通常只使用默认

# %% [markdown]
# 循环![image.png](attachment:93634b95-a324-4797-a975-ab103baac091.png)

# %% [markdown]
# 要吸取的教训是，我们不能盲目地计算一个函数。我们总是需要仔细分析我们的算法，以寻找潜在的陷阱。然而，没有什么神奇的方法，唯一的指导方针是理解机器不能正确表示所有数字的事实。

# %% [markdown]
# 9.90625转化为二进制![image.png](attachment:a9490012-fda1-46e2-a18a-c26559969b97.png)

# %% [markdown]
# 尾数![image.png](attachment:7ad0918e-fa15-4104-8c6b-f948e1bda011.png)

# %% [markdown]
# 因此类似于科学计数法，机器中我们的数字总可以表示为![image.png](attachment:f43e17b8-c3ab-4567-b71e-78b0f8fb541c.png)

# %% [markdown]
# 对于一个32位的单精度值，8位给指数，1位给符号，23位给尾数，即REAL(4)

# %% [markdown]
# 数值计算总推荐使用双精度浮点数

# %% [markdown]
# a是b和c的差值![image.png](attachment:baf6d17c-d7af-4a91-92c4-30ce194e830f.png)

# %% [markdown]
# $\epsilon$代表了float有限精度带来的误差，同理可以写为![image.png](attachment:e61cf5a5-b9af-45ff-b6c4-b3eba074f902.png)

# %% [markdown]
# 如果b~c的话，容易带来舍入误差，这是因为我们在减去两个大小相等的数，剩下的只是这两个数中最不有效的部分。![image.png](attachment:0603053c-afc8-4919-922a-28b40c0e4866.png)可能的误差会非常大

# %% [markdown]
# 相对误差可写为![image.png](attachment:d3452b4f-7117-48e0-b036-78779c625f09.png)

# %% [markdown]
# ![image.png](attachment:15e209d6-304f-4e84-8418-3b7990a5d230.png)

# %% [markdown]
# ![image.png](attachment:b5196320-f33b-432a-827a-a78c6b31d775.png)

# %% [markdown]
# **TYPE**:Fortran中使用type关键字来定义派生类型 (其他语言中叫做结构体或者类)![image.png](attachment:9baf9454-10b5-48d4-800f-754b51fc0c20.png)DIMENSION(:)一维可分配数组

# %% [markdown]
# ![image.png](attachment:ac22bf14-c334-4db7-b889-0e89a5bd3e5c.png)

# %% [markdown]
# **函数求导数：** 导数定义为![image.png](attachment:a6f29521-341b-4078-aec1-967648a641d2.png)

# %% [markdown]
# 在求导点附近泰勒展开：![image.png](attachment:854a801c-e4d9-40c0-b703-73798067d597.png)

# %% [markdown]
# 可认为计算的导数是：![image.png](attachment:ca48cfc6-1796-4466-80fb-fb04bdd8565d.png)和实际的导数相差高阶项

# %% [markdown]
# 即求两点的斜率![image.png](attachment:96357cde-8ada-4d44-b3ff-143b0ab66eca.png)

# %% [markdown]
# 显然h越小越接近真实导数，但是h变小会带来f(x)和f(x-h)相近引起的舍入误差，因此在$x_0$的左右泰勒展开：![image.png](attachment:c2c64504-346b-4d98-96fb-ed53bd62f111.png)

# %% [markdown]
# 并且相减：![image.png](attachment:1aa62012-a298-4c6b-89ad-7d05f4c49a2e.png)

# %% [markdown]
# 由于误差项是$h^2$所以截断误差被优化了，同理拓展到五点求导：![image.png](attachment:763725f9-a2ab-4f9a-a51a-6767bd64cbdf.png)

# %% [markdown]
# ![image.png](attachment:4727ac26-ac30-4816-bbc6-59492a9a143e.png)

# %% [markdown]
# 通常求导写作：![image.png](attachment:da318675-56eb-4780-9a5d-5d955f175c9f.png)

# %% [markdown]
# 原理是，可用临近点泰勒展开的相加或相减来凑项：![image.png](attachment:ded03a6d-f62e-40ee-8554-eb6b4b67ddab.png)![image.png](attachment:9ccea5da-dcc6-469e-8b59-0303ad744eef.png)

# %% [markdown]
# 使用allocate分配内存：首先定义变量可被分配![image.png](attachment:d7e2e553-edc9-40f5-a6cb-6e6abe9ba694.png)

# %% [markdown]
# 分配：![image.png](attachment:4f276383-17df-4318-9e25-5916fda7d019.png)并紧接着初始化
#
# 并在结束时取消内存：![image.png](attachment:1c845961-1e25-4376-966e-416be1d2ad82.png)

# %% [markdown]
# **Richardson的递延外推法**:尽管减小h能够减小截断误差，但是最终会导致失去数值精度，因此可以采用递推的方法：![image.png](attachment:2cb962b6-8966-44b5-8d61-6acc174ff26a.png)

# %% [markdown]
# ![image.png](attachment:1f151259-b0aa-45e4-9170-9fb48c39140f.png)

# %% [markdown]
# 方法形如：![image.png](attachment:352e0561-d1f4-4c19-a95a-9ea845803fed.png)

# %% [markdown]
# **gnuplot**: ![image.png](attachment:ffb2cfb4-ee38-42e2-8ffc-27a5f7bc5028.png)-->提取两行作为x,y![image.png](attachment:2a24daf2-0ccc-4a86-930d-93da91badc35.png)(1:2列with lines)

# %% [markdown]
# ![image.png](attachment:af842bb5-b92b-40da-b1cf-8896e966a881.png)散点

# %% [markdown]
# 保存图形：![image.png](attachment:40f4095a-2f13-4ec5-8c92-2f6135c5d8f9.png)

# %% [markdown]
# **线性代数**：![image.png](attachment:f77a6e7b-bab6-42d7-a91b-07672398cc63.png)

# %% [markdown]
# 矢量的三种乘法![image.png](attachment:08df0e06-dcc9-4ce0-8320-4f9a8563922d.png)

# %% [markdown]
# 矩阵在计算机中表示为数字串，在Fortran中是列顺序的![image.png](attachment:598db894-ec04-4eca-bd68-c3937a7f868c.png)因此对于一个矩阵加法：![image.png](attachment:15841e51-5597-4293-9a73-6c41cc0f9a7b.png)变换如图的i,j顺序能够提高速度（因为相同的j的矩阵元存储在一起）

# %% [markdown]
# 矩阵乘法：![image.png](attachment:1cb27fa6-c375-43ec-a361-6e5b39f96b66.png)直接可用包装好的函数a=MATMUL(b,c)代替

# %% [markdown]
# 对于一矩阵乘法，需要（包含加法）2n^3次运算，如果两个相乘的矩阵都是上三角的![image.png](attachment:cb585511-c6fe-4e53-aa60-f931e329be83.png)那么可以1/6的运算次数

# %% [markdown]
# ![image.png](attachment:a2714c47-31ab-4ce0-ad88-0488364badb7.png)必须满足i>j才！=0

# %% [markdown]
# 构造数组：![image.png](attachment:e510b887-3ed3-4a93-b043-6113945a028e.png)

# %% [markdown]
# **矩阵的LU分解**：![image.png](attachment:9ac6f4bd-df61-4d12-a59a-68d5c62a2f61.png)如果A存在行列式且A非奇异，那么A存在LU分解且唯一（行列式![image.png](attachment:5a7f4aae-1e36-4102-9c59-5392eb767203.png)）

# %% [markdown]
# 求LU分解矩阵元的方式：![image.png](attachment:e578b093-0d2b-478e-adb4-4d2528be07c1.png)

# %% [markdown]
# 对上述B矩阵的对角元为1的LU分解，称为Doolittle’s算法。对于C的对角元为1的LU分解，称为Crout’s算法。当C是B的转置，有Cholesky分解算法（前提是A是实的、对称的、正定的）

# %% [markdown]
# ![image.png](attachment:4433c611-47bc-4a67-841a-b3430af3b42c.png)

# %% [markdown]
# Doolittle's算法有时需要对原矩阵进行转动，来避免丢失数值精度。

# %% [markdown]
# 求解线性方程：![image.png](attachment:9cbec071-7cb3-42c2-87bf-bd89e024e697.png)即![image.png](attachment:8cce4b97-1e9d-4473-9fb2-b8b12aabe6f8.png)

# %% [markdown]
# ![image.png](attachment:bf78b5c0-d171-444c-affa-5ca5e12ee647.png)由于B的对角线是1，所以行列式为1，![image.png](attachment:eac7e420-3f0c-4e20-8930-57400872278f.png)

# %% [markdown]
# ![image.png](attachment:da11be36-898d-4c0d-b4ea-9dc270983922.png)先矩阵分解，再求线形方程

# %% [markdown]
# **矩阵的逆和行列式**：n阶矩阵求行列式，逆序数法（最基础的方法）![image.png](attachment:3462c143-ab7c-4c34-aee6-aff000a48164.png)

# %% [markdown]
# 求矩阵的逆：需要计算n^2次行列式，因此需要LU法简化

# %% [markdown]
# ![image.png](attachment:27af3332-07db-47de-8032-370e5a1e85c7.png)分解![image.png](attachment:c886965e-8273-4bb4-9fbc-42f6118e40eb.png)B的行列式为1，因此A的行列式就是C的行列式，就是对角元之积

# %% [markdown]
# ![image.png](attachment:70d3d999-7e7f-4f7a-b455-39ba25b0bb75.png)由于三角矩阵的逆对应同样形状的三角矩阵，所以(D是B的逆)![image.png](attachment:846ddf9d-5ed1-4f6c-9ea7-c44c9720221e.png)

# %% [markdown]
# ![image.png](attachment:70656545-e03a-447a-92dd-18039ea38cd3.png)由类似的方法给出C的逆![image.png](attachment:c0eca778-43b4-49dd-8f3a-9dc3ab51c043.png)

# %% [markdown]
# ![image.png](attachment:9854a2cc-79fe-47f8-b804-50272fd36ad6.png)

# %% [markdown]
# **非线性方程和多项式的根**:

# %% [markdown]
# **时间相关函数**：磁化强度的时间位移自相关![image.png](attachment:92c2a696-5a24-4f67-9830-1b8fab0294ce.png)

# %% [markdown]
# **特征值问题**： ![image.png](attachment:33e5434f-56a3-43e3-b7c4-c3742c4a6df9.png)
#
# ![image.png](attachment:7126c21e-3bc9-4209-b6d6-27330ac79ff4.png)
#
# 仅当满足![image.png](attachment:34f956b6-03af-40da-94ca-e69eca630b9f.png)有解

# %% [markdown]
# 所以可以看成n个解的![image.png](attachment:5eb48b68-ebc8-4817-9b8d-a73d523cce72.png)

# %% [markdown]
# ![image.png](attachment:a422bf90-b3f4-42a7-b8eb-78ec92fa5e1a.png)![image.png](attachment:9d4aa944-3065-4da8-9d79-c66de4127a08.png)

# %% [markdown]
# 因此，求矩阵的特征值，相当于将矩阵对角化或三对角线化，（通过一系列相似变换）

# %% [markdown]
# 正交相似变换：![image.png](attachment:093030b9-5b24-48dd-abaf-47212f178d21.png)

# %% [markdown]
# 相似变换后的矩阵具有相同的特征值，但是特征向量一般不同

# %% [markdown]
# Jocobi方法:旋转矩阵是一个正交变换矩阵，形如![image.png](attachment:b2a757ce-817c-4140-b8f3-3f0e0976c38e.png)（相当于在欧式空间绕某个轴旋转），那么进行一系列相似变换直到非对角元的平方和到0（或接近0），对于实数大型矩阵，该算法比三角化慢一些![image.png](attachment:20261228-b7f5-4e58-a042-416da108a491.png)--->0

# %% [markdown]
# 总是选定一个绝对值最大的非对角元，$s_{kl}$使之相似变换后为0，所以旋转矩阵要这样取![image.png](attachment:514d8e36-76e8-46f6-b709-6a9e77282ff2.png)重复操作直到矩阵的非对角元范数小于某个值

# %% [markdown]
# Householder方法（三角化）：先将矩阵三对角线化，再对角化，原因是对角化三对角线矩阵快得多

# %% [markdown]
# 三对角线化要求进行![image.png](attachment:b7e4e66b-34e3-4187-82c2-7d8db725e75e.png)这样的变换，直到![image.png](attachment:01a7e6f0-589e-43d8-ab9d-85c7bbaa457b.png)![image.png](attachment:1f42e872-a1ed-48f9-9dec-037e1f06e018.png)

# %% [markdown]
# 再通过旋转来对角化

# %% [markdown]
# **薛定谔方程转化为矩阵本征值问题：**![image.png](attachment:a7f037f3-e0c2-4908-9696-abfa4def3977.png)

# %% [markdown]
# ![image.png](attachment:039a3278-5fd4-4584-9ea3-439cf2d881b2.png)
